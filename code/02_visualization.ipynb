# %% [markdown]
# # Final Project: Text Analysis and Uncovering Demographic or Regional Differences in Family Caregiver Experiences
#
# ### *May Khine, Andrea Robang, Mark Lekina*
#
# ## Visualization notebook

# %% [markdown]
# ### Load packages

# %%
## helpful packages
import pandas as pd
import numpy as np
import random
import re
import nltk
import spacy
import en_core_web_sm
import gensim
import scipy as sp
from scipy.special import logsumexp

## vectorizer
from sklearn.feature_extraction.text import CountVectorizer

## sentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

## lda
from gensim import corpora
from gensim.models.coherencemodel import CoherenceModel

## nltk imports
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk import pos_tag
from nltk.tokenize import word_tokenize, wordpunct_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

# libraries for data visualization
import pyLDAvis
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# suppress warnings
import warnings
warnings.filterwarnings('ignore')

## load pipeline
nlp = en_core_web_sm.load()

## repeated printouts and wide-format text
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Load data

# %%
# load datasets
dartmouth_data = pd.read_excel("../data/DartmouthDataSet.xlsx")
start_feis_data = pd.read_excel("../data/STARTFEISData.xlsx")

# %% [markdown]
# ### Subset to relevant columns

# %%
# define columns of interest in each dataset
# Dartmouth dataset
cols_interest_dartmouth = ['Local ID', 'Region', 'County', 'Date Enrolled in START',
                 'Date of birth', 'Gender', 'Race', 'Ethnicity', 'Level of Intellectual Disability']

# START FEIS dataset
cols_interest_start = ['Respondent ID #  (SIRS Local ID)', 'Start Date', 'End Date',
                       'Was there any particular service that your\nfamily member needed that was not available?',
                       'If yes, please describe the service.',
                       'What\nadvice would you give to service planners regarding the mental health service\nneeds of persons with IDD and their families?']

# subset to relevant columns in each dataset
demo_df = dartmouth_data[cols_interest_dartmouth].copy()
resp_df = start_feis_data[cols_interest_start].copy()

# %% [markdown]
# ### Merge relevant columns from both datasets

# %%
# merge demographic data from dartmouth_data with the responses from start_feis_data into a common dataframe
combined_data = pd.merge(demo_df, resp_df, how="inner", 
                              left_on='Local ID', right_on='Respondent ID #  (SIRS Local ID)')

# define the two open response columns
open_cols = ['If yes, please describe the service.', 
        'What\nadvice would you give to service planners regarding the mental health service\nneeds of persons with IDD and their families?']

# print the difference in dataframe shapes
demo_df.shape
resp_df.shape
combined_data.shape

# print the head of the resulting dataframe
combined_data.head()
# Out:
# (4986, 9)
# (1940, 6)
# (1097, 15)
#   Local ID                             Region      County  \
# 0  8008815     California : CA START East Bay     Alameda
# 1  6570649  California : CA START San Andreas  Santa Cruz
# 2   434021                New York : Region 3      Orange
# 3  6580618  California : CA START San Andreas  Santa Cruz
# 4   354280                New York : Region 3      Warren
#
#   Date Enrolled in START Date of birth  Gender                    Race  \
# 0             2020-12-29    2006-11-13    Male          Other: Mexican
# 1             2020-12-29    1999-02-07  Female  Unknown, not collected
# 2             2020-12-28    2001-12-24  Female                   White
# 3             2020-12-23    2004-12-21    Male                   White
# 4             2020-12-21    2005-09-04    Male  Unknown, not collected
#
#                                   Ethnicity Level of Intellectual Disability  \
# 0  Hispanic - specific origin not specified                             Mild
# 1  Hispanic - specific origin not specified                           Severe
# 2                    Not of Hispanic origin                       Borderline
# 3                    Not of Hispanic origin                         Moderate
# 4                    Unknown, not collected                             Mild
#
#   Respondent ID #  (SIRS Local ID)          Start Date            End Date  \
# 0                          8008815 2021-01-14 16:59:09 2021-01-14 17:13:45
# 1                          6570649 2021-01-05 13:35:02 2021-01-05 13:42:08
# 2                           434021 2020-12-28 11:49:28 2020-12-28 11:55:53
# 3                          6580618 2021-01-22 11:42:45 2021-01-22 11:50:28
# 4                           354280 2021-02-16 16:02:49 2021-02-16 16:38:02
#
#   Was there any particular service that your\nfamily member needed that was not available?  \
# 0                                                                                       No
# 1                                                                                      Yes
# 2                                                                                      Yes
# 3                                                                                      Yes
# 4                                                                                      Yes
#
#                                                                                                                                                                                                                                                                                                                                                                      If yes, please describe the service.  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                     NaN
# 1                                                                                                                                                                                                                                                                                                                            A counselor was not and has not been made available for the last six months.
# 2                                                                                                                                                                                                                                                                                                                                                                               In-home behavior support
# 3  "After Trevorâ€™s psychiatrist left the office, the office also stopped taking his insurance and as a result, Trevor went without a psychiatrist for a while. Trevorâ€™s family tried their best to get him in with other psychiatrists, but struggled to find one that would treat Trevor. Through SARC, Trevor was referred to Hope Services and will begin seeing a psychiatrist there on 1.27.21."
# 4                                                                                                                                                                                                                                                                                                  At home off hour support on phone or in person/respite, have removed for the night for safety reasons.
#
#                                                                                                                                                                                                   What\nadvice would you give to service planners regarding the mental health service\nneeds of persons with IDD and their families?
# 0                                                                                                                                                                                                                                                                                                                                NaN
# 1  â€œPlease be aware of her conditions and diagnosis, so many professionals are unfamiliar with the medical history of Citlalli. It is discouraging when professionals do not know Citlalli, but make recommendations for her. Also, it is discouraging when the professionals do not take the opinions of the family seriously.â€
# 2                                                                                                                                                                                                                                                                                                                                NaN
# 3                                                                                                                                                                                                                                                                                                  Declined to answer/did not know.
# 4                                                                                                                                                                                          Listen to the parents, take what parents report seriously, and provide tips, not just call the cops, have options/walk parent through it.

# %% [markdown]
# ### Topic modeling on the combined dataset

# %% [markdown]
# **Question 1**: What themes and keywords are most prevalent in responses from individuals with IDD and their families highlighting still-standing mental health needs and services?

# %% [markdown]
# **Response**: We will perform topic modeling on the two free response columns of the combined dataframe and determine the prevalent topics, as well as the most frequent words in each topic.

# %% [markdown]
# ### Define a function to preprocess the responses in the relevant columns

# %%
def process_step(string):
    # Get stopwords
    list_stopwords = stopwords.words("english")

    # Add custom stopwords (if present)
    custom_words_toadd = []#["need", "needs", "family", "families", "service", "services", "provide", "provides"]
    list_stopwords_new = list_stopwords + custom_words_toadd

    # Initialize stemmer
    porter = PorterStemmer()
    
    # perform necessary steps and return preprocessed text (or a blank string on error)
    try:
        nostop_listing = [word for word in wordpunct_tokenize(string)
                          if word not in list_stopwords_new]
        clean_listing = [porter.stem(word) for word in nostop_listing
                         if word.isalpha() and len(word) > 3]    # Can change length of word here
#         clean_listing = [word for word in clean_listing if word not in ["need", "servic", "famili", "provid"]]
        clean_listing_str = " ".join(clean_listing)   
        
        return(clean_listing_str)
    except:
        return("")

# %% [markdown]
# ### Apply `process_step` to the open response columns and return new columns for the processed text

# %%
# preprocess the responses in each open response column
for col in open_cols:
    combined_data["processed_{col}".format(col=col)] = [process_step(response) for response in combined_data[col]]
    
# print the head of the resulting columns
rel_cols = open_cols + ["processed_{col}".format(col=col) for col in open_cols]
combined_data[rel_cols].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                      If yes, please describe the service.  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                     NaN
# 1                                                                                                                                                                                                                                                                                                                            A counselor was not and has not been made available for the last six months.
# 2                                                                                                                                                                                                                                                                                                                                                                               In-home behavior support
# 3  "After Trevorâ€™s psychiatrist left the office, the office also stopped taking his insurance and as a result, Trevor went without a psychiatrist for a while. Trevorâ€™s family tried their best to get him in with other psychiatrists, but struggled to find one that would treat Trevor. Through SARC, Trevor was referred to Hope Services and will begin seeing a psychiatrist there on 1.27.21."
# 4                                                                                                                                                                                                                                                                                                  At home off hour support on phone or in person/respite, have removed for the night for safety reasons.
#
#                                                                                                                                                                                                   What\nadvice would you give to service planners regarding the mental health service\nneeds of persons with IDD and their families?  \
# 0                                                                                                                                                                                                                                                                                                                                NaN
# 1  â€œPlease be aware of her conditions and diagnosis, so many professionals are unfamiliar with the medical history of Citlalli. It is discouraging when professionals do not know Citlalli, but make recommendations for her. Also, it is discouraging when the professionals do not take the opinions of the family seriously.â€
# 2                                                                                                                                                                                                                                                                                                                                NaN
# 3                                                                                                                                                                                                                                                                                                  Declined to answer/did not know.
# 4                                                                                                                                                                                          Listen to the parents, take what parents report seriously, and provide tips, not just call the cops, have options/walk parent through it.
#
#                                                                                                                                                                                                processed_If yes, please describe the service.  \
# 0
# 1                                                                                                                                                                                                             counselor made avail last month
# 2                                                                                                                                                                                                                       home behavior support
# 3  after trevorâ psychiatrist left offic offic also stop take insur result trevor went without psychiatrist trevorâ famili tri best psychiatrist struggl find would treat trevor through sarc trevor refer hope servic begin see psychiatrist
# 4                                                                                                                                                                             home hour support phone person respit remov night safeti reason
#
#                                         processed_What\nadvice would you give to service planners regarding the mental health service\nneeds of persons with IDD and their families?
# 0
# 1  œpleas awar condit diagnosi mani profession unfamiliar medic histori citlal discourag profession know citlal make recommend also discourag profession take opinion famili serious
# 2
# 3                                                                                                                                                                 declin answer know
# 4                                                                                                    listen parent take parent report serious provid tip call cop option walk parent

# %% [markdown]
# ### Define a function to perform topic modeling

# %%
def topic_model(col, num_topics):
    # compute parameters using helper function
    params = set_model_params(col)
    text_raw_dict = params[1]
    corpus_fromdict = params[2]
    
    # train the model
    ldamod = gensim.models.ldamodel.LdaModel(corpus_fromdict, 
                                    num_topics = num_topics, id2word=text_raw_dict, 
                                    passes=20, alpha = 'auto',
                                    per_word_topics = True, random_state = 0)

    # return trained model, tokenized text, dictionary and document-term matrix
    return ldamod

def set_model_params(col):
    # tokenize each response
    text_raw_tokens = [wordpunct_tokenize(text) for text in col]

    # use gensim to create a dictionary of all unique words across documents
    text_raw_dict = corpora.Dictionary(text_raw_tokens)

    # apply dictionary to tokenized texts
    corpus_fromdict = [text_raw_dict.doc2bow(text) for text in text_raw_tokens]
    
    # return parameters
    return (text_raw_tokens, text_raw_dict, corpus_fromdict)

# %%
# define columns on which to perform topic modelling
preprocessed_cols = ["processed_{col}".format(col=col) for col in open_cols]
preprocessed_names = ["response_service", "response_advice"]

preprocessed_dict = dict(zip(preprocessed_names, preprocessed_cols))
preprocessed_dict
# Out:
# {'response_service': 'processed_If yes, please describe the service.',
#  'response_advice': 'processed_What\nadvice would you give to service planners regarding the mental health service\nneeds of persons with IDD and their families?'}

# %% [markdown]
# ### Define function to visualize the topics given a column of a dataframe

# %%
# apply topic modelling function to each column
def visualize_topics(col):
    lda_model = topic_model(col, num_topics=7)
    tokenized_text, text_raw_dict, corpus_fromdict = set_model_params(col)
    
    # tabulate the topics and respective top words
    table = topic_model_rhea(tokenized_text, text_raw_dict, corpus_fromdict, topic_num=7)

    # visualize the topics
    pyLDAvis.enable_notebook()
    vis = pyLDAvis.gensim_models.prepare(lda_model, corpus_fromdict, text_raw_dict)
    
    # return visualization
    return table, vis

# %% [markdown]
# ### Functions to help tabulate the data
# >Originally in 01_topic_modeling.ipynb

# %%
def prep_topicdata(df):
    # filtering out empty strings, words that do not appear in many documents
    df = df[df.proc_advice != ""].copy()
    tokenized_text = [wordpunct_tokenize(one_text) for one_text in 
                                      df.proc_advice]
    text_proc_dict = corpora.Dictionary(tokenized_text)
    text_proc_dict.filter_extremes(no_below = round(df.shape[0]*0.02),
                             no_above = round(df.shape[0]*0.98))
    
    corpus_fromdict_proc = [text_proc_dict.doc2bow(one_text) 
                   for one_text in tokenized_text]

    return tokenized_text, text_proc_dict, corpus_fromdict_proc

def topic_model_rhea(tokenized_text, text_proc_dict, corpus_fromdict_proc, topic_num):
        
    # create model
    ldamod = gensim.models.ldamodel.LdaModel(corpus_fromdict_proc, 
                                         num_topics = topic_num, id2word=text_proc_dict, 
                                         passes=6, alpha = 'auto',
                                        per_word_topics = True, random_state = 0)

    # get topics using frex values
    frex_words = create_topic_word_data(ldamod, corpus_fromdict_proc, frex_w=0.7)

    # get top 10 words per topic and collect in a list
    frex_topwords = frex_words.sort_values(['frex'], axis=0, ascending = False).groupby('topic').head(10)    
    frex_wordlist = frex_topwords.groupby('topic').agg({'word': [lambda x: list(x)]})
    frex_word_df = pd.DataFrame(frex_wordlist)
    frex_word_df.columns = ["top_words"]
    return(frex_word_df)

def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size


def frex(mod, w=0.7):
    """Calculate FREX for all words in a topic model.

    See R STM package for details.

    """
    log_beta = np.log(mod.get_topics())
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    out = 1. / (w / exclusivity_ecdf + (1 - w) / freq_ecdf)
    return out

def create_topic_word_data(mod, corpus, frex_w=0.7):
    """Create data frame with topic-word information.

    Parameters
    ------------
    mod: :class:`gensim.models.LdaModel`
        Fitted LDA model
    corpus: list
        Corpus in the same input format as required by
        :class:`gensim.models.LdaModel`.
    frex_w: float
        Weight to use in FREX calculations.
        
    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.


        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
        :lift: ``float``. Lift score
        :relevance: ``float``. Relevance score

    """
    id2word = mod.id2word
    term_topics = pd.DataFrame(mod.get_topics())
    term_topics.index.name = "topic"
    term_topics.reset_index(inplace=True)
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
        }, columns=("word_id", "word"))
    term_topics = pd.melt(term_topics, id_vars=["topic"],
                          var_name="word_id",
                          value_name="prob").\
        merge(words, left_on="word_id", right_on="word_id")
    term_topics['frex'] = np.ravel(frex(mod, w=frex_w), order="F")
    return term_topics


def compute_coherence_values(corpus_fromdict_proc, tokenized_text, text_proc_dict):
    # initialize possible # of topics in the range 2 to 10
    limit=10; start=2; step=1;
    coherence_values = []
    model_list = []
    
    # create models for each number of topics and coherence model values
    for num in range(start, limit, step):
        ldamod = gensim.models.ldamodel.LdaModel(corpus_fromdict_proc, 
                                                 num_topics = num, id2word=text_proc_dict, 
                                                 passes=20, alpha = 'auto',
                                                 per_word_topics = True, random_state = 0)    
        model_list.append(ldamod)
        coherencemodel = CoherenceModel(model=ldamod, texts=tokenized_text, dictionary=text_proc_dict, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())


    # Show graph
    x = range(start, limit, step)
    print(x)
    print(coherence_values)

    plt.plot(x, coherence_values)
    plt.xlabel("Num Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()

    return model_list, coherence_values

# %% [markdown]
# ### Visualize topic modelling on the preprocessed columns for the entire corpus

# %%
for col_name in preprocessed_dict:
    col = preprocessed_dict[col_name]
    table, vis = visualize_topics(combined_data[col])
    
    # define pathnames for the tables and graphs
    path = '../output/topic_model_vis/{col_name}/whole_corpus/model_{col_name}'.format(col_name=col_name)
    graph_path = path + ".html"
    table_path = path + ".csv"
    
    print("visualizing topics and top words in {col_name} for complete corpus ...".format(col_name=col_name))
    print("see '{path}' if pyLDAvis graph is not displayed\n".format(path=path))
    
    # display the table and save it to .csv file
    print(table, '\n')
    table.to_csv(table_path)
    
    # visualize and save the output
    pyLDAvis.display(vis)
    pyLDAvis.save_html(vis, graph_path)
# Out:
# visualizing topics and top words in response_service for complete corpus ...
# see '../output/topic_model_vis/response_service/whole_corpus/model_response_service' if pyLDAvis graph is not displayed
#
#                                                                                      top_words
# topic
# 0            [psychiatri, appoint, life, psychiatr, state, coach, sonâ, genet, syndrom, tutor]
# 1           [speech, therapi, respons, parent, occup, camp, hour, overnight, clarif, diagnost]
# 2               [intervent, more, mobil, autism, divers, plan, crisi, everyth, transport, med]
# 3      [afterschool, neurolog, olymp, describ, sign, american, identifi, lika, engag, austist]
# 4                  [school, psychiatrist, take, set, time, after, blood, sure, trevor, doctor]
# 5               [hous, function, escal, thing, with, doe, bigger, disord, agit, neurobehaivor]
# 6         [habilit, residenti, commun, local, respit, aid, waiver, rehabilit, option, patient]
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el837411402202610221768265275265"></div>
# <script type="text/javascript">
#
# var ldavis_el837411402202610221768265275265_data = {"mdsDat": {"x": [0.03865300227786053, 0.14995277708882473, 0.07637596865072886, -0.20498388725205194, 0.0807215935386565, -0.03569705681751833, -0.10502239748650084], "y": [0.22835352138577716, -0.009380645274469896, -0.08576362517045184, 0.029947931814966022, -0.046791026036313625, -0.04579535413578711, -0.07057080258372074], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [22.227760527741765, 19.47144410434931, 17.542777678018016, 14.935683397126793, 12.65992181252198, 6.61049868047342, 6.5519137997687205]}, "tinfo": {"Term": ["respit", "therapi", "crisi", "home", "school", "behavior", "program", "support", "servic", "commun", "help", "habilit", "group", "psychiatrist", "residenti", "intervent", "speech", "need", "psychiatri", "health", "would", "more", "skill", "hous", "like", "special", "medic", "placement", "counsel", "care", "habilit", "residenti", "commun", "local", "waiver", "year", "aid", "rehabilit", "youth", "away", "holiday", "development", "list", "opportun", "respit", "option", "wait", "patient", "still", "door", "half", "progress", "front", "process", "section", "grief", "adolesc", "livin", "unfortun", "explor", "counsel", "inform", "facil", "weekend", "placement", "program", "trauma", "health", "servic", "psychiatr", "home", "care", "worker", "staff", "assist", "need", "mental", "access", "avail", "hospit", "famili", "intervent", "more", "mobil", "plan", "divers", "everyth", "autism", "unit", "crisi", "transport", "prevent", "therapeut", "med", "teenag", "coordin", "pediatr", "foster", "address", "issu", "direct", "advoc", "frustart", "region", "remov", "emot", "rahimul", "signific", "safeti", "reason", "phone", "hospit", "servic", "outpati", "bed", "care", "emerg", "adult", "disabl", "connect", "mental", "support", "behavior", "individu", "health", "respit", "comm", "access", "school", "home", "inpati", "manag", "medic", "group", "help", "respons", "speech", "parent", "therapi", "occup", "camp", "children", "clarif", "diagnost", "studi", "bcba", "none", "swim", "hors", "system", "possibl", "physic", "massag", "prompt", "rapid", "sleep", "method", "verbal", "sensori", "integr", "manager", "independat", "safe", "alon", "singl", "train", "skill", "activ", "treatment", "inpati", "hour", "overnight", "cope", "polic", "cover", "better", "social", "behavior", "respit", "group", "help", "crisi", "individu", "manag", "provid", "comm", "famili", "appropri", "recreat", "need", "work", "home", "care", "servic", "psychiatrist", "take", "set", "after", "blood", "trevor", "sure", "school", "time", "drawn", "condit", "return", "without", "tri", "hope", "begin", "trevor\u00e2", "hillsid", "offic", "doctor", "place", "put", "reluct", "vulner", "calm", "easier", "indiv", "make", "case", "sinc", "program", "alex", "anger", "want", "need", "get", "increas", "dentist", "also", "counsel", "provid", "medic", "famili", "activ", "work", "servic", "manag", "insur", "social", "weekend", "would", "train", "home", "appropri", "residenti", "psychiatri", "life", "state", "son\u00e2", "genet", "syndrom", "tutor", "special", "appoint", "coach", "background", "found", "check", "were", "play", "joseph", "cancel", "februray", "robinson", "januari", "figur", "within", "bother", "exposur", "classroom", "money", "achiev", "sooner", "outlet", "empath", "long", "therapist", "support", "psychiatr", "much", "home", "behavior", "placement", "skill", "took", "health", "medic", "specialist", "involv", "mental", "build", "counselor", "manag", "social", "clinic", "outsid", "therapi", "servic", "commun", "train", "need", "counsel", "evalu", "psych", "afterschool", "neurolog", "mentorship", "olymp", "lika", "friend", "austist", "sign", "describ", "american", "identifi", "engag", "male", "diagnosi", "behaviorist", "open", "eval", "throughout", "rspite", "hygien", "serv", "improv", "resit", "aggress", "neuropsych", "dental", "donald", "cri", "respond", "like", "would", "treat", "group ...
# visualizing topics and top words in response_advice for complete corpus ...
# see '../output/topic_model_vis/response_advice/whole_corpus/model_response_advice' if pyLDAvis graph is not displayed
#
#                                                                                      top_words
# topic
# 0      [profession, self, rural, appoint, citlal, discourag, histori, habit, with, acknowledg]
# 1                 [keep, meet, daughter, dysregul, need, behavior, have, regard, list, proper]
# 2       [social, say, unknown, psychiatr, therapist, fragil, insist, nurs, welcom, practition]
# 3                   [none, go, sure, figur, first, structur, child, everyth, baselin, coverag]
# 4             [earli, advic, live, choos, respit, experienc, disabl, environ, medicaid, skill]
# 5                   [answer, call, even, personnel, kind, wiiht, outcom, polic, enrol, period]
# 6                [continu, health, follow, consist, much, diagnosi, order, import, good, find]
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el837411402205684718085144350135"></div>
# <script type="text/javascript">
#
# var ldavis_el837411402205684718085144350135_data = {"mdsDat": {"x": [0.05382981194382329, 0.10596877359843325, 0.027393284009258632, 0.05543650324227223, -0.032410098799067304, -0.058934172637583035, -0.1512841013571371], "y": [0.039291069468140066, -0.025904324521212975, 0.0984531227503822, -0.005558197768050486, -0.03739797559489542, -0.14501244072164454, 0.07612874638728101], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [23.890672199668504, 20.766115835316302, 17.211111556047882, 15.991382530409314, 8.292296871345247, 7.508661223227275, 6.339759783985478]}, "tinfo": {"Term": ["answer", "none", "need", "help", "provid", "more", "avail", "famili", "listen", "take", "health", "crisi", "sure", "area", "time", "medic", "servic", "call", "member", "resourc", "go", "know", "children", "understand", "report", "find", "option", "earli", "advic", "would", "meet", "keep", "dysregul", "proper", "mind", "adequ", "hear", "readili", "paperwork", "easier", "noth", "moment", "decreas", "intens", "less", "greater", "info", "avail", "daughter", "have", "list", "regard", "convey", "display", "howev", "inabl", "mediat", "modifi", "short", "hab", "need", "access", "behavior", "program", "peopl", "help", "term", "give", "medic", "servic", "there", "also", "they", "more", "children", "inform", "resourc", "client", "staff", "question", "provid", "educ", "want", "support", "parent", "individu", "make", "famili", "care", "better", "crisi", "continu", "consist", "order", "good", "state", "ongo", "benefit", "prefer", "satisfi", "cohes", "cover", "custom", "field", "local", "health", "center", "diagnosi", "much", "case", "follow", "attent", "connect", "popul", "worker", "coordin", "find", "appt", "therapeut", "figueora", "success", "would", "import", "like", "speak", "opwdd", "famili", "need", "support", "servic", "member", "mental", "think", "individu", "serv", "work", "provid", "assist", "care", "access", "parent", "home", "resourc", "plan", "educ", "peopl", "inform", "help", "earli", "advic", "choos", "experienc", "environ", "soon", "difficult", "seek", "deal", "current", "multipl", "live", "effici", "skill", "inclus", "across", "burden", "drag", "intak", "despit", "mandat", "reduc", "busi", "damag", "grandmoth", "reasonbal", "properti", "remot", "cop", "walk", "enough", "take", "placement", "respit", "face", "provid", "offer", "will", "consid", "mani", "serious", "medicaid", "disabl", "hour", "children", "creat", "report", "awar", "servic", "person", "commun", "work", "time", "inform", "help", "issu", "support", "crisi", "make", "parent", "mental", "famili", "listen", "individu", "more", "none", "go", "figur", "first", "structur", "sure", "baselin", "coverag", "paid", "wrong", "someth", "taunt", "guard", "probabl", "turn", "allow", "everyth", "someon", "individual\u00e2", "staf", "complic", "resid", "jennif", "alberta", "easili", "tri", "clarifi", "alcohol", "done", "father", "listen", "option", "child", "lot", "treatment", "understand", "time", "leav", "mother", "given", "know", "patient", "famili", "make", "parent", "need", "better", "care", "there", "servic", "commun", "feel", "support", "like", "emerg", "clear", "provid", "crisi", "inform", "individu", "look", "social", "unknown", "psychiatr", "therapist", "say", "research", "fragil", "behaviorist", "expert", "insist", "nurs", "practition", "prescript", "welcom", "vanish", "white", "reason", "black", "jump", "round", "exist", "balanc", "hous", "conclus", "willing", "depth", "tire", "commin", "side", "fail", "especi", "team", "account", "manag", "more", "opportun", "direct", "life", "best", "caregiv", "take", "medic", "famili", "contact", "activ", "get", "find", "resourc", "would", "group", "involv", "know", "mental", "need", "health", "avail", "help", "care", "individu", "support", "work", "servic", "person", "fund", "profession", "self", "rural", "citlal", "discourag", "histori", "habit", "with", "acknowledg", "area", "appoint", "unfamiliar", "condit", "\u0153pleas ...

# %% [markdown]
# ### **Question 2**: How do they vary with racial groups, age, and nature of disability over the course of the pandemic?

# %% [markdown]
# **Response**: We repeat the same procedure, but also examine correlation between the demographics and topic proportions/top topics

# %% [markdown]
# ### Subset the data by demographic

# %%
# define demographics of interest
demographics_cols = ['Gender', 'Level of Intellectual Disability', 'Race']

# specify the different categories in each demographic
# in the case of 'Race', responses from patients who identified as White made up a huge proportion,
# therefore we will compare them with the remainder of the responses (see cell below)
demographics_subsets = [['Male', 'Female'],
                        ['Mild', 'Moderate', 'Severe'], 
                        ['White']]

# combine them in a dictionary
demographics_dict = dict.fromkeys(demographics_cols , None)

for idx, col in enumerate(demographics_cols):
    demographics_dict[col] = demographics_subsets[idx]

demographics_dict
# Out:
# {'Gender': ['Male', 'Female'],
#  'Level of Intellectual Disability': ['Mild', 'Moderate', 'Severe'],
#  'Race': ['White']}

# %%
advice_col_1 = 'processed_If yes, please describe the service.'
advice_col_2 = ('processed_What\nadvice would you give to service planners regarding the mental'
              ' health service\nneeds of persons with IDD and their families?')

# %% [markdown]
# ### Perform topic modeling on the preprocessed columns for each subset

# %%
# loop through each response
for col_name in preprocessed_dict:
    response_col = preprocessed_dict[col_name]
    
    # loop through each demographic
    for demo in demographics_dict:
        # loop through each subset
        for subset in demographics_dict[demo]:
            # visualize topics
            col = combined_data[combined_data[demo] == subset][response_col]
            table, vis = visualize_topics(col)
    
            # define pathnames for the tables and graphs
            # display outputs and save them to outputs folder
            path = "../output/topic_model_vis/{col_name}/by_demographic/{demo}/model_{subset}".format(demo=demo,
                                                                                                           subset=subset,
                                                                                                           col_name=col_name)
            
            graph_path = path + ".html"
            table_path = path + ".csv"
            
            print("visualizing topics and top words in {col_name} for subset: {demo} == {subset} ...".format(demo=demo,
                                                                                                             subset=subset,
                                                                                                             col_name=col_name))
            print("(see {path} to display pyLDAvis graph)\n".format(path=path))
            
            # display the table
            print(table, '\n')
            table.to_csv(table_path)

            # uncomment to display graph
            # pyLDAvis.display(vis)
            pyLDAvis.save_html(vis, graph_path)
        
# add race subset (excluding responses from White patients)
# loop through each response
for col_name in preprocessed_dict:
    response_col = preprocessed_dict[col_name]
    
    # specify subset and create visualization
    col = combined_data[combined_data['Race'] != 'White'][response_col]
    table, vis = visualize_topics(col)

    # save output to html and .csv file
    path = "../output/topic_model_vis/{col_name}/by_demographic/Race/model_not_White".format(col_name=col_name)
    graph_path = path + ".html"
    table_path = path + ".csv"

    print("visualizing topics and top words in {col_name} for subset: Race != White ...".format(col_name=col_name))
    print("(see {path} to display pyLDAvis graph)\n".format(path=path))
    # uncomment to display graph
    # pyLDAvis.display(vis)
    pyLDAvis.save_html(vis, graph_path)
    
    # display the table
    print(table, '\n')
    table.to_csv(table_path)
# Out:
# visualizing topics and top words in response_service for subset: Gender == Male ...
# (see ../output/topic_model_vis/response_service/by_demographic/Gender/model_Male to display pyLDAvis graph)
#
#                                                                                                   top_words
# topic
# 0      [mental, placement, health, psychiatrist, rehabilit, psychiatr, syndrom, better, life, psychologist]
# 1                          [crisi, intervent, respons, speech, occup, therapi, comm, prevent, anger, mobil]
# 2                           [psychiatri, blood, comprehens, neurolog, get, medicaid, sure, take, go, vocat]
# 3                             [habilit, counsel, care, autism, unit, inpati, teenag, progress, front, half]
# 4                                 [parent, program, work, train, hillsid, med, much, divers, great, mirror]
# 5                        [aid, build, outpati, regular, basi, specialist, flexibl, diagnost, clarif, rehab]
# 6                              [set, would, appropri, trevor, coordin, like, come, therapeut, fall, return]
#
# visualizing topics and top words in response_service for subset: Gender == Female ...
# (see ../output/topic_model_vis/response_service/by_demographic/Gender/model_Female to display pyLDAvis graph)
#
#                                                                                        top_words
# topic
# 0                  [staff, provid, behavior, home, respit, residenti, camp, appli, like, counti]
# 1                 [habilit, hospit, bernstein, state, much, know, believ, donâ, paper, collabor]
# 2                   [crisi, help, respons, polic, young, moment, hand, dispatch, post, appropri]
# 3                          [health, aid, mental, worker, hour, obtaint, build, they, get, navig]
# 4      [function, psychiatrist, time, connect, lower, address, separ, she, elizabeth, compliant]
# 5           [famili, year, close, session, psycholoci, yanilka, enough, psychosoci, there, fund]
# 6           [trauma, specialist, languag, engag, interpret, deaf, meet, especi, identifi, covid]
#
# visualizing topics and top words in response_service for subset: Level of Intellectual Disability == Mild ...
# (see ../output/topic_model_vis/response_service/by_demographic/Level of Intellectual Disability/model_Mild to display pyLDAvis graph)
#
#                                                                                 top_words
# topic
# 0      [therapi, behavior, speech, advoc, center, region, frustart, enough, everi, meant]
# 1           [bed, avail, go, psychiatrist, facil, open, psychiatr, regular, basi, divers]
# 2         [emerg, outpati, parent, mani, holiday, overnight, intervent, wait, step, long]
# 3       [person, school, weekend, program, support, after, tutor, train, night, appropri]
# 4        [residenti, placement, group, help, social, counsel, skill, local, aid, resourc]
# 5        [hous, respons, mental, access, health, sonâ, genet, syndrom, prioriti, definit]
# 6      [habilit, servic, commun, famili, comm, describ, christoph, engag, especi, disabl]
#
# visualizing topics and top words in response_service for subset: Level of Intellectual Disability == Moderate ...
# (see ../output/topic_model_vis/response_service/by_demographic/Level of Intellectual Disability/model_Moderate to display pyLDAvis graph)
#
#                                                                                      top_words
# topic
# 0             [psychiatrist, trevor, after, offic, counsel, assist, trevorâ, begin, see, hope]
# 1                 [placement, want, divers, like, calm, afraid, outsid, mother, vulner, polic]
# 2                      [med, progress, half, front, door, process, still, mani, year, monitor]
# 3             [psychiatri, special, help, neurolog, daili, hospit, escal, physic, comm, paper]
# 4      [patient, medicaid, peopl, appoint, paid, februray, januari, robinson, cancel, comphab]
# 5           [behavior, respit, specialist, home, plan, therapist, commun, habilit, get, appli]
# 6               [speech, occup, direct, self, appropri, expert, local, meet, therapi, respons]
#
# visualizing topics and top words in response_service for subset: Level of Intellectual Disability == Severe ...
# (see ../output/topic_model_vis/response_service/by_demographic/Level of Intellectual Disability/model_Severe to display pyLDAvis graph)
#
#                                                                                 top_words
# topic
# 0        [avail, last, counselor, month, structur, activ, habilit, recreat, commun, made]
# 1                  [self, worker, hire, direct, commun, also, manag, bcba, aid, frustrat]
# 2            [follow, find, never, assist, offer, servic, holiday, hard, doctor, respons]
# 3              [crisi, mental, focus, show, individu, mobil, especi, more, servic, enrol]
# 4            [client, residenti, doe, kevin, someon, need, medicaid, control, have, help]
# 5      [care, includ, extend, provid, otand, weekend, commuiti, therapist, involv, opwdd]
# 6         [group, transport, there, could, joseph, medic, psychiatr, will, financi, home]
#
# visualizing topics and top words in response_service for subset: Race == White ...
# (see ../output/topic_model_vis/response_service/by_demographic/Race/model_White to display pyLDAvis graph)
#
#                                                                                        top_words
# topic
# 0              [manag, function, could, lika, austist, olymp, friend, exposur, separ, classroom]
# 1          [habilit, staff, psychiatri, respons, enough, hillsid, bed, engag, languag, identifi]
# 2                     [hous, worker, home, therapist, intervent, abl, polic, med, some, process]
# 3            [trevor, alex, divers, blood, offic, psychiatrist, trevorâ, appoint, possibl, step]
# 4              [health, servic, mental, activ, assist, individu, autism, anger, transit, specif]
# 5      [placement, specialist, inpati, psych, she, compliant, elizabeth, appli, when, residenti]
# 6                 [speech, occup, school, medicaid, build, therapi, return, waiver, emerg, comm]
#
# visualizing topics and top words in response_advice for subset: Gender == Male ...
# (see ../output/topic_model_vis/response_advice/by_demographic/Gender/model_Male to display pyLDAvis graph)
#
#                                                                                 top_words
# topic
# 0            [answer, structur, go, flexibl, taunt, turn, guard, someon, effici, momentâ]
# 1      [take, treatment, serious, say, function, obtain, clinic, previou, count, chicken]
# 2            [prescrib, advoc, doctor, proper, less, amount, consist, kind, decreas, set]
# 3         [intervent, leav, crisi, wait, even, staff, personnel, contact, when, research]
# 4                 [listen, made, member, face, deal, express, allow, address, didn, cope]
# 5               [fund, coordin, come, what, coverag, adequ, cohes, unknown, reduc, intak]
# 6             [none, issu, earli, regard, attent, caregiv, speak, often, experienc, dont]
#
# visualizing topics and top words in response_advice for subset: Gender == Female ...
# (see ../output/topic_model_vis/response_advice/by_demographic/Gender/model_Female to display pyLDAvis graph)
#
#                                                                                          top_words
# topic
# 0      [profession, request, dysregul, citlal, servic, discourag, member, treatment, involv, more]
# 1                             [have, crash, moment, knew, cours, frank, found, form, felf, assign]
# 2                     [difficult, creativ, amount, specif, will, medicaid, get, kid, sure, togeth]
# 3                 [parent, better, avail, believ, baselin, child, includ, attend, speak, identifi]
# 4                          [health, share, hear, train, continu, option, also, want, camp, mother]
# 5               [none, appoint, behavior, realli, sever, feel, patricia, abl, everi, psychiatrist]
# 6                 [answer, team, particular, willing, especi, occur, judg, indiviu, know, greater]
# visualizing topics and top words in response_advice for subset: Level of Intellectual Disability == Mild ...
# (see ../output/topic_model_vis/response_advice/by_demographic/Level of Intellectual Disability/model_Mild to display pyLDAvis graph)
#
#                                                                                         top_words
# topic
# 0          [situat, meet, report, present, obtain, background, psych, evalu, closest, underestim]
# 1      [appoint, simpli, enough, prescrib, doctor, psychiatrist, patricia, regard, someth, reach]
# 2                [experienc, continu, often, import, program, sever, mani, œwrongâ, truli, versu]
# 3              [none, live, expand, explain, gaurdian, sinc, environ, contact, figueora, weekend]
# 4                        [specif, taunt, turn, go, guard, structur, donâ, supervis, crise, adequ]
# 5               [there, dysregul, medic, high, behavior, system, coverag, challeng, could, treat]
# 6                          [answer, servic, talk, know, awar, earli, life, moir, compon, financi]
#
# visualizing topics and top words in response_advice for subset: Level of Intellectual Disability == Moderate ...
# (see ../output/topic_model_vis/response_advice/by_demographic/Level of Intellectual Disability/model_Moderate to display pyLDAvis graph)
#
#                                                                                top_words
# topic
# 0              [answer, mani, avail, figur, baselin, system, tri, resid, gather, easili]
# 1          [train, polic, personnel, mention, acces, strong, time, effici, age, explain]
# 2                 [none, patienc, issu, ongo, given, referr, consist, plan, role, think]
# 3                   [advic, pursu, book, full, choos, compil, hour, base, suppli, start]
# 4      [client, unknown, program, order, placement, enough, common, either, mind, dosag]
# 5         [satisfi, util, earli, person, diagnos, leav, report, comfort, probabl, advoc]
# 6              [opwdd, need, famili, help, keep, understand, there, proper, also, sever]
#
# visualizing topics and top words in response_advice for subset: Level of Intellectual Disability == Severe ...
# (see ../output/topic_model_vis/response_advice/by_demographic/Level of Intellectual Disability/model_Severe to display pyLDAvis graph)
#
#                                                                                 top_words
# topic
# 0      [none, profession, citlal, discourag, call, emerg, clear, intervent, beyond, mean]
# 1                  [answer, patient, close, well, work, case, manag, much, wether, adequ]
# 2         [like, option, safe, particular, opwdd, children, kirsch, fund, waiver, enough]
# 3           [group, upset, appoint, special, hope, that, home, publicli, dentist, dental]
# 4       [especi, opportun, open, period, transit, assisst, commun, with, resourc, provid]
# 5         [they, acc, immedi, quicker, patienc, anzwer, crisi, understand, servic, avail]
# 6              [known, situat, think, obtain, awar, carpent, make, contact, referr, need]
#
# visualizing topics and top words in response_advice for subset: Race == White ...
# (see ../output/topic_model_vis/response_advice/by_demographic/Race/model_White to display pyLDAvis graph)
#
#                                                                               top_words
# topic
# 0         [say, anxieti, struggl, intervent, proper, heighten, possibl, arm, run, flee]
# 1      [option, creat, choos, medicaid, health, serv, mental, express, form, psychiatr]
# 2           [awar, hospit, baselin, step, staf, public, overal, confront, check, doubl]
# 3              [none, treat, dysregul, self, experi, thi, allot, true, expand, aggress]
# 4        [month, week, everi, appoint, coverag, probabl, patricia, intak, face, simpli]
# 5       [answer, structur, sure, ongo, appropri, concern, collabor, center, kind, meet]
# 6                    [specif, good, team, coordin, want, get, sinc, activ, first, ryan]
#
# visualizing topics and top words in response_service for subset: Race != White ...
# (see ../output/topic_model_vis/response_service/by_demographic/Race/model_not_White to display pyLDAvis graph)
#
#                                                                                      top_words
# topic
# 0          [like, placement, sure, residenti, person, counselor, attend, evalu, reason, night]
# 1            [set, staff, go, expens, trauma, saturday, hospit, continuili, wraparound, desir]
# 2            [comm, provid, camp, address, better, none, treatment, summer, therapeut, system]
# 3          [therapi, direct, specialist, self, counsel, group, live, psychiatri, cope, famili]
# 4               [habilit, commun, doctor, outpati, limit, tutor, program, psych, meet, parent]
# 5         [psychiatrist, health, respons, mental, crisi, prevent, aid, genet, intervent, sonâ]
# 6      [patient, overnight, medicaid, wiht, covid, coordin, obtaint, skip, challang, outburst]
#
# visualizing topics and top words in response_advice for subset: Race != White ...
# (see ../output/topic_model_vis/response_advice/by_demographic/Race/model_not_White to display pyLDAvis graph)
#
#                                                                                       top_words
# topic
# 0       [inform, profession, access, right, citlal, discourag, resid, complic, express, easili]
# 1      [answer, interact, less, continu, donâ, patienc, compassion, within, interview, anxieti]
# 2                            [none, differ, opportun, activ, brace, plu, ill, tip, parent, cop]
# 3                    [have, lack, experienc, cover, medicaid, when, much, option, better, hear]
# 4                      [give, face, especi, staff, nystart, cope, covid, restrict, wiht, relat]
# 5                   [need, think, center, offer, caregiv, opwdd, appropri, age, unknown, sever]
# 6             [school, leav, symptom, level, caretak, stress, discuss, figur, everyday, dislik]
